# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from utils import load, dump
from evaluate import eval, Evaluator
from os import getcwd
from tqdm import tqdm
import torch

# %%
root = f'{getcwd()}/..'
path = lambda p: f'{root}/../out/{p}'

# %%
testset = load(f'{root}/data/prd_backtick-se_cowait_annotated.json')

def evaluate(predict):    
    y_true = []
    y_pred = []

    for pr in tqdm(testset):
        title = pr['title']
        pcat = predict(title)
        tcat = pr['category']

        y_true.append(tcat)
        y_pred.append(pcat)
    
    eval(y_true, y_pred)

def progress(model):
    ev = Evaluator(path(model))
    ev.plot_progress()
    evaluate(ev.predict)

def compare(*models):
    model_files = [*map(path, models)]
    evaluators = [*map(Evaluator, model_files)]
    Evaluator.compare(*evaluators)

# %% [markdown]
# ## Let's evaluate the transformer classifiers

# %% [markdown]
# ### Frozen base results for each checkpoint
# DistilBERT and CodeBERTa showing best base config results

# %%
compare(
    'codebert-base_model_385k_unbalanced_1e-03_solid.pt',
    'BERTOverflow_model_385k_unbalanced_1e-03_solid.pt',
    'bert-base-uncased_model_385k_unbalanced_1e-03_solid.pt',
    'CodeBERTa-small-v1_model_385k_unbalanced_1e-03_solid.pt',
    'distilbert-base-uncased_model_385k_unbalanced_1e-03_solid.pt',
)

# %% [markdown]
# ### Thaw progress CodeBERTa
# Model reaction to unfreezing a couple of base layers.

# %%
compare(
    'CodeBERTa-small-v1_model_385k_unbalanced_1e-03_solid.pt',
    'CodeBERTa-small-v1_model_385k_unbalanced_1e-03_thaw1.pt',
    'CodeBERTa-small-v1_model_385k_unbalanced_1e-03_thaw2.pt',
    'CodeBERTa-small-v1_model_385k_unbalanced_1e-03_thaw5.pt',
)

# %% [markdown]
# ### Differing learning rates

# %%
model_files = [*map(path, (
    'CodeBERTa-small-v1_model_385k_unbalanced_1e-03_thaw5.pt',
    'CodeBERTa-small-v1_model_385k_unbalanced_5e-04_thaw5.pt'
))]

evaluators = [*map(Evaluator, model_files)]
Evaluator.compare(*evaluators)

# %%
ev = Evaluator(path('CodeBERTa-small-v1_model_385k_unbalanced_5e-04_thaw5.pt'))
ev.plot_progress()
evaluate(ev.predict)
# Out:
# 100%|██████████| 180/180 [00:06<00:00, 29.20it/s]
#                 precision    recall  f1-score   support
#
#       fix-bugs       0.33      0.69      0.44        32
#   new-features       0.53      0.33      0.41        49
#  documentation       0.17      0.25      0.20         8
# non-functional       0.59      0.46      0.52        91
#
#       accuracy                           0.46       180
#      macro avg       0.40      0.43      0.39       180
#   weighted avg       0.51      0.46      0.46       180
#
# [[22  2  2  6]
#  [12 16  3 18]
#  [ 0  1  2  5]
#  [33 11  5 42]]

# %% [markdown]
# ### Best of all bases

# %%
model_files = [*map(path, (
    'codebert-base_model_385k_unbalanced_1e-03_solid.pt',
    'BERTOverflow_model_385k_unbalanced_1e-03_solid.pt',
    'bert-base-uncased_model_385k_unbalanced_1e-03_solid.pt',
    'CodeBERTa-small-v1_model_385k_unbalanced_5e-04_thaw5.pt',
    'distilbert-base-uncased_model_385k_unbalanced_1e-03_thaw5.pt'
))]

evaluators = [*map(Evaluator, model_files)]
Evaluator.compare(*evaluators)

# %%
model_files = [*map(path, (
    'distilbert-base-uncased_model_385k_unbalanced_1e-03_solid.pt',
    'distilbert-base-uncased_model_385k_unbalanced_1e-03_thaw2.pt',
    'distilbert-base-uncased_model_385k_unbalanced_1e-03_thaw5.pt',
))]

evaluators = [*map(Evaluator, model_files)]
Evaluator.compare(*evaluators)
